# %% [markdown]
# # Project Zephr Baseline Exploration
#
# Quick inspection notebook for loading config, reading outputs, and plotting resolved links.

# %%
from pathlib import Path

import geopandas as gpd
import pandas as pd

root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
outputs = root / 'data' / 'outputs'
place_to_building = pd.read_parquet(outputs / 'place_to_building.parquet')
place_to_building.head()
